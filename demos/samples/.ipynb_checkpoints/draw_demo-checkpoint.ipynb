# %%
import sys
import numpy as np
from numpy import pi, arccos, cos, sin, tan, mean
import matplotlib.pyplot as plt
import getopt
import warnings
warnings.filterwarnings("ignore")

# %%
#sys.path.append("/project/6049244/perry/scripts") # Narval
sys.path.append("/project/6049244/perry/scripts") # cedar
import detectorLayout

# %%
import glob
#DMCfiles = np.sort(glob.glob('/lustre06/project/6035200/perry/Data/HV100mm_bulk_10kevents_may10_51230510_0000??.root')) # Narval
DMCfiles = np.sort(glob.glob('/project/6049244/perry/Data/HV100mm_bulk_10kevents_may10_51230510_0000??.root')) # Cedar

# %%
plt.figure(figsize=(4, 4), dpi=100)
detectorLayout.drawDetOutline(DMCfiles[0], color='black', lw = 2, ls = '-')
detectorLayout.drawChanOutline(DMCfiles[0], color='cornflowerblue', lw = 1.5, ls ='--', side=1, chantype=1, labels=1)
plt.xlabel('X [mm]')
plt.ylabel('Y [mm]')
plt.title('HV100mm Side 1')

plt.figure(figsize=(4, 4), dpi=100)
detectorLayout.drawDetOutline(DMCfiles[0], color='black', lw = 2, ls = '-')
detectorLayout.drawChanOutline(DMCfiles[0], color='cornflowerblue', lw = 1.5, ls ='--', side=2, chantype=1, labels=1)
plt.xlabel('X [mm]')
plt.ylabel('Y [mm]')
plt.title('HV100mm Side 2')
# Out:
# Welcome to JupyROOT 6.28/10
# Text(0.5, 1.0, 'HV100mm Side 2')
