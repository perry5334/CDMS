# %%
import cdms
import numpy as np
import os, sys 
import ROOT
from cats.cdataframe import CDataFrame
from CDMSDataCatalog import CDMSDataCatalog
import supercuts
import glob

import matplotlib.pyplot as plt
# %matplotlib inline

CDMS = os.environ["CDMS"] # set in .bash_profile
stylesheet = os.path.join(CDMS,"scripts","stylesheets","blues.mplstyle")
plt.style.use(stylesheet)

sys.path.append(os.path.join(os.path.join(CDMS,"scripts")))
import setup
# Out:
# Welcome to JupyROOT 6.28/10

# %%
ProdTag = 'CUTE_T3_GeActivation_v2.1.1_V05-00_P0.2.'

# %%
filepath = np.sort(glob.glob(f'/scratch/group/mitchcomp/CDMS/data/CDMS/CUTE/R37/Processed/Tests/{ProdTag}/Submerged/{ProdTag}_232312??_??????.root'))

# %%
det = 1 # detector number

df = CDataFrame("rqDir/zip"+str(det), filepath, friends = [[x+":rqDir/eventTree" for x in filepath]])

# %%
## Apply some basic data quality filters and get the RQs you're interested in
logfile = '"cute_tower3testing.log"'
df = df.Define("LEDLogFile", logfile) 
df = df.CDefine("LEDOn", supercuts.ledOn_old, ["EventTime", "LEDLogFile"])
df = df.Filter("!LEDOn")
df_filtered = df.Filters(["TriggerType == 1", "TriggerDetectorNum=="+str(det), "PTOFamps>0"])

# %%
RQs = (["SeriesNumber", "PTOFamps","PTOFchisqLF", "PTOFdelay", "EventNumber", "EventTime"] + 
       ['P' + label + 'S' + sequence + 'OFamps' for sequence in ['1', '2'] for label in ['A', 'B', 'C', 'D', 'E', 'F']] + 
       ['P' + label + 'S' + sequence + 'sat' for sequence in ['1', '2'] for label in ['A', 'B', 'C', 'D', 'E', 'F']])
df_rqs = df_filtered.AsNumpy(RQs)

# %%
RQs = ['P' + label + 'S' + sequence for sequence in ['1', '2'] for label in ['A', 'B', 'C', 'D', 'E', 'F']]

plt.figure(figsize=(4,3), dpi=200)
plt.scatter(df_rqs['PTOFamps']*1e6, np.sum(np.array([df_rqs[RQ+'sat'] for RQ in RQs]), axis = 0), s = 1)
plt.xlabel(r"PTOFamps [$\mathrm{\mu A}$]")
plt.ylabel("sum(P&S#sat)")
# Out:
# Text(0, 1, 'sum(P&S#sat)')

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(df_rqs['PTOFamps']*1e6, bins=np.linspace(0, 150, 151), alpha = 1)
plt.hist(df_rqs['PTOFamps']*1e6, bins=np.linspace(0, 150, 151), histtype='step', color = 'black', lw = 0.2)
plt.yscale('log')
plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / $\mathrm{\mu A}$")
# Out:
# Text(0, 1, 'Count / $\\mathrm{\\mu A}$')

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(df_rqs['PTOFamps']*1e6, bins=np.linspace(0, 30, 101), alpha = 1)
plt.hist(df_rqs['PTOFamps']*1e6, bins=np.linspace(0, 30, 101), histtype='step', color = 'black', lw = 0.2)
plt.yscale('log')
plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / (0.3 $\mathrm{\mu A}$)")
# Out:
# Text(0, 1, 'Count / (0.3 $\\mathrm{\\mu A}$)')

# %%
L_peak_bins = np.linspace(2.5, 5, 51)
K_peak_bins = np.linspace(22, 30, 41)
L_peak_data = df_rqs['PTOFamps'][(df_rqs['PTOFamps'] >= 2.5e-6) & (df_rqs['PTOFamps'] <= 5e-6)] * 1e6
K_peak_data = df_rqs['PTOFamps'][(df_rqs['PTOFamps'] >= 22e-6) & (df_rqs['PTOFamps'] <= 30e-6)] * 1e6

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(L_peak_data, bins=L_peak_bins, alpha = 1)
plt.hist(L_peak_data, bins=L_peak_bins, histtype='step', color = 'black', lw = 0.2)
plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / (0.05 $\mathrm{\mu A}$)")
# Out:
# Text(0, 1, 'Count / (0.05 $\\mathrm{\\mu A}$)')

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(K_peak_data, bins=K_peak_bins, alpha = 1)
plt.hist(K_peak_data, bins=K_peak_bins, histtype='step', color = 'black', lw = 0.2)

plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / (0.2 $\mathrm{\mu A}$)")
# Out:
# Text(0, 1, 'Count / (0.2 $\\mathrm{\\mu A}$)')

# %% [markdown]
# # Let's fit the k-peak with a Gaussian, a Johnson, and a flat background
# $$
# model = c_1 \cdot Gauss_1(\mu_1,\sigma_1) + c_2 \cdot Johnson_2(\mu_2,\lambda_2,\gamma_2,\delta_2) +  (1-c_1- c_2) \cdot Uniform
# $$

# %%
# make a frame
def make_frame(obs, *objects):
    frame = obs.frame()
    for obj in objects:
        obj.plotOn(frame)
    return frame

# draw a frame
def make_plot(frame):
    c = ROOT.TCanvas()
    frame.Draw()
    c.Draw()
    # need this for the plot not to be removed!
    ROOT.SetOwnership( c, False )

# %%
counts, bin_edges = np.histogram(K_peak_data, bins=K_peak_bins)
binWidth = np.diff(K_peak_bins)[0]
bin_centers = bin_edges[:-1] + binWidth / 2
counts_err = np.sqrt(counts)

# Observable
x = ROOT.RooRealVar("x", "x", 22, 30)

# Parameters
mean_1 = ROOT.RooRealVar("#mu1", "#mu", 26, 22, 30)
sigma_1 = ROOT.RooRealVar("#sigma1", "#sigma", 1, 0.1, 10)
# Parameters
mean_2 = ROOT.RooRealVar("#mu2", "#mu", 27.5, 24, 30)
lambda_2 = ROOT.RooRealVar("#lambda2", "#lambda", 1, 0.1, 4)
delta_2 = ROOT.RooRealVar("#delta2", "#delta", 4, 0.1, 5)
gamma_2 = ROOT.RooRealVar("#gamma2", "#gamma", 3, 0.1, 5)

# Distributions
g1 = ROOT.RooGaussian("g1", "g1", x, mean_1, sigma_1)
j2 = ROOT.RooJohnson("j2", "j2", x, mean_2, lambda_2, gamma_2, delta_2)
flat = ROOT.RooUniform("flat", "flat", x)

# Weight of distributions
frac1 = ROOT.RooRealVar("c1", "#c", 0.5, 0.0, 1.0)
frac2 = ROOT.RooRealVar("c2", "#c", 0.2, 0.0, 1.0)

# Convert numpy array into RooFit object
pdf = ROOT.RooAddPdf("model", "model", ROOT.RooArgList(g1, j2, flat), ROOT.RooArgList(frac1, frac2))
# 
#data = ROOT.RooDataSet.from_numpy({"x": K_peak_data},[x],name='2_gauss',title='2_gauss')
data = ROOT.RooDataHist.from_numpy(counts, [x], bins=[K_peak_bins])

# %%
nll = pdf.createNLL(data)
m = ROOT.RooMinimizer(nll)
m.migrad()

fit_result = m.save()

frame = make_frame(x,data,pdf)

pdf.paramOn(frame)
make_plot(frame)
# Out:
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 #delta2      4.00000e+00  4.90000e-01    1.00000e-01  5.00000e+00
#      2 #gamma2      3.00000e+00  4.90000e-01    1.00000e-01  5.00000e+00
#      3 #lambda2     1.00000e+00  3.90000e-01    1.00000e-01  4.00000e+00
#      4 #mu1         2.60000e+01  8.00000e-01    2.20000e+01  3.00000e+01
#      5 #mu2         2.75000e+01  6.00000e-01    2.40000e+01  3.00000e+01
#      6 #sigma1      1.00000e+00  4.50000e-01    1.00000e-01  1.00000e+01
#      7 c1           5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      8 c2           2.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=4604.52 FROM MIGRAD    STATUS=INITIATE       67 CALLS          68 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta2      4.00000e+00   4.90000e-01   0.00000e+00   6.27492e+01
#    2  #gamma2      2.78951e-01   4.90000e-01  -2.14009e+00  -5.00479e+00
#    3  #lambda2     1.00000e+00   3.90000e-01   0.00000e+00  -2.06505e+02
#    4  #mu1         2.60000e+01   8.00000e-01   0.00000e+00  -1.91033e+03
#    5  #mu2         2.75000e+01   6.00000e-01   0.00000e+00  -9.45762e+01
#    6  #sigma1      1.00000e+00   4.50000e-01   0.00000e+00   8.83332e+02
#    7  c1           5.00000e-01   1.00000e-01   0.00000e+00  -6.45639e+02
#    8  c2           2.00000e-01   1.00000e-01   0.00000e+00  -8.87855e+02
#                                ERR DEF= 0.5
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529
# [#0] WARNING:Eval -- RooAddPdf::updateCoefCache(model WARNING: sum of PDF coefficients not in range [0-1], value=1.529 (no more will be printed)
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=1.95332	#gamma2=0.260693	#lambda2=1.20399	#mu1=26.5272	#mu2=27.5074	#sigma1=0.800773	c1=0.947082	c2=0.581922
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.30509e-07/2.00723,j2 = 3.84076e-05/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 8.88851e-07/2.00723,j2 = 5.31097e-05/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 3.22017e-06/2.00723,j2 = 7.39201e-05/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.09607e-05/2.00723,j2 = 0.000103584/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 3.50513e-05/2.00723,j2 = 0.000146177/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000105312/2.00723,j2 = 0.000207795/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000297279/2.00723,j2 = 0.00029763/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000788422/2.00723,j2 = 0.000429654/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00196455/2.00723,j2 = 0.000625274/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00459911/2.00723,j2 = 0.000917554/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0101157/2.00723,j2 = 0.00135796/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0209038/2.00723,j2 = 0.00202722/0.999137,flat = 1/8), !coefficients=(c1 = 0.947082,c2 = 0.581922)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 1.95332,#gamma2 = 0.260693,#lambda2 = 1.20399,#mu1 = 26.5272,#mu2 = 27.5074,#sigma1 = 0.800773,c1 = 0.947082,c2 = 0.581922)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=1.58797	#gamma2=0.208143	#lambda2=1.48496	#mu1=26.801	#mu2=27.6602	#sigma1=0.583162	c1=0.998906	c2=0.764123
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 7.74614e-15/1.46177,j2 = 0.00116305/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.15936e-13/1.46177,j2 = 0.0014232/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.54266e-12/1.46177,j2 = 0.00174801/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.82491e-11/1.46177,j2 = 0.00215517/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.91925e-10/1.46177,j2 = 0.00266764/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.79448e-09/1.46177,j2 = 0.00331536/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.49164e-08/1.46177,j2 = 0.00413747/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.10232e-07/1.46177,j2 = 0.00518538/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 7.24217e-07/1.46177,j2 = 0.0065268/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 4.23008e-06/1.46177,j2 = 0.00825119/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.19658e-05/1.46177,j2 = 0.010477/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000101406/1.46177,j2 = 0.0133612/0.983863,flat = 1/8), !coefficients=(c1 = 0.998906,c2 = 0.764123)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 1.58797,#gamma2 = 0.208143,#lambda2 = 1.48496,#mu1 = 26.801,#mu2 = 27.6602,#sigma1 = 0.583162,c1 = 0.998906,c2 = 0.764123)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=1.87805	#gamma2=0.102108	#lambda2=0.822406	#mu1=26.4958	#mu2=27.5804	#sigma1=0.630894	c1=0.964265	c2=0.744769
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.87176e-11/1.58142,j2 = 1.53318e-06/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.48652e-10/1.58142,j2 = 2.20483e-06/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.94711e-09/1.58142,j2 = 3.19818e-06/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.37894e-08/1.58142,j2 = 4.68136e-06/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 8.83189e-08/1.58142,j2 = 6.91826e-06/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.11586e-07/1.58142,j2 = 1.03278e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.68002e-06/1.58142,j2 = 1.5583e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.26974e-05/1.58142,j2 = 2.37793e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.44058e-05/1.58142,j2 = 3.6723e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00021083/1.58142,j2 = 5.74354e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000738879/1.58142,j2 = 9.10454e-05/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00234191/1.58142,j2 = 0.000146396/0.999751,flat = 1/8), !coefficients=(c1 = 0.964265,c2 = 0.744769)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 1.87805,#gamma2 = 0.102108,#lambda2 = 0.822406,#mu1 = 26.4958,#mu2 = 27.5804,#sigma1 = 0.630894,c1 = 0.964265,c2 = 0.744769)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=0.461923	#gamma2=0.21199	#lambda2=0.996299	#mu1=26.3328	#mu2=27.5211	#sigma1=0.781526	c1=0.801355	c2=0.534139
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 4.26708e-07/1.95899,j2 = 0.0224087/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.65142e-06/1.95899,j2 = 0.0235916/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.9861e-06/1.95899,j2 = 0.0248761/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.0323e-05/1.95899,j2 = 0.0262746/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 6.46232e-05/1.95899,j2 = 0.0278016/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000192464/1.95899,j2 = 0.0294737/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000536867/1.95899,j2 = 0.0313105/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00140263/1.95899,j2 = 0.0333348/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00343223/1.95899,j2 = 0.0355739/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00786628/1.95899,j2 = 0.0380598/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0168857/1.95899,j2 = 0.0408309/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0339492/1.95899,j2 = 0.043933/0.650884,flat = 1/8), !coefficients=(c1 = 0.801355,c2 = 0.534139)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 0.461923,#gamma2 = 0.21199,#lambda2 = 0.996299,#mu1 = 26.3328,#mu2 = 27.5211,#sigma1 = 0.781526,c1 = 0.801355,c2 = 0.534139)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=2.46389	#gamma2=0.167296	#lambda2=0.913043	#mu1=26.2761	#mu2=27.5399	#sigma1=0.841592	c1=0.724293	c2=0.502732
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 4.50065e-06/2.10955,j2 = 3.54905e-09/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.42279e-05/2.10955,j2 = 6.30084e-09/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 4.25089e-05/2.10955,j2 = 1.13312e-08/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00012003/2.10955,j2 = 2.06547e-08/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000320315/2.10955,j2 = 3.81871e-08/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000807858/2.10955,j2 = 7.16603e-08/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0019256/2.10955,j2 = 1.36595e-07/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00433782/2.10955,j2 = 2.64686e-07/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00923527/2.10955,j2 = 5.2184e-07/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0185823/2.10955,j2 = 1.04771e-06/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0353366/2.10955,j2 = 2.14409e-06/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0635071/2.10955,j2 = 4.47665e-06/0.999995,flat = 1/8), !coefficients=(c1 = 0.724293,c2 = 0.502732)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 2.46389,#gamma2 = 0.167296,#lambda2 = 0.913043,#mu1 = 26.2761,#mu2 = 27.5399,#sigma1 = 0.841592,c1 = 0.724293,c2 = 0.502732)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=1.79541	#gamma2=0.275055	#lambda2=0.95734	#mu1=26.215	#mu2=27.5088	#sigma1=0.825462	c1=0.677873	c2=0.446628
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 4.0138e-06/2.06912,j2 = 3.01113e-05/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.30427e-05/2.06912,j2 = 4.09196e-05/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 3.99653e-05/2.06912,j2 = 5.59912e-05/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00011548/2.06912,j2 = 7.7168e-05/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000314653/2.06912,j2 = 0.000107161/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000808471/2.06912,j2 = 0.000149996/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00195885/2.06912,j2 = 0.000211709/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00447553/2.06912,j2 = 0.000301434/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00964257/2.06912,j2 = 0.000433142/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0195905/2.06912,j2 = 0.000628418/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0375323/2.06912,j2 = 0.000920974/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0678061/2.06912,j2 = 0.00136404/0.999497,flat = 1/8), !coefficients=(c1 = 0.677873,c2 = 0.446628)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 1.79541,#gamma2 = 0.275055,#lambda2 = 0.95734,#mu1 = 26.215,#mu2 = 27.5088,#sigma1 = 0.825462,c1 = 0.677873,c2 = 0.446628)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=2.4071	#gamma2=0.21643	#lambda2=0.952002	#mu1=26.2344	#mu2=27.5276	#sigma1=0.857406	c1=0.631896	c2=0.44462
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 8.93342e-06/2.14918,j2 = 1.9225e-08/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.67725e-05/2.14918,j2 = 3.28582e-08/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 7.59854e-05/2.14918,j2 = 5.68266e-08/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00020424/2.14918,j2 = 9.9502e-08/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000519901/2.14918,j2 = 1.76499e-07/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00125334/2.14918,j2 = 3.1736e-07/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00286147/2.14918,j2 = 5.78831e-07/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00618698/2.14918,j2 = 1.07163e-06/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0126688/2.14918,j2 = 2.01532e-06/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0245677/2.14918,j2 = 3.85282e-06/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0451193/2.14918,j2 = 7.49352e-06/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0784747/2.14918,j2 = 1.48388e-05/0.99999,flat = 1/8), !coefficients=(c1 = 0.631896,c2 = 0.44462)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 2.4071,#gamma2 = 0.21643,#lambda2 = 0.952002,#mu1 = 26.2344,#mu2 = 27.5276,#sigma1 = 0.857406,c1 = 0.631896,c2 = 0.44462)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=2.3277	#gamma2=0.300238	#lambda2=0.963144	#mu1=26.181	#mu2=27.5092	#sigma1=0.827784	c1=0.633376	c2=0.422093
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.2751e-06/2.07494,j2 = 1.03906e-07/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.686e-05/2.07494,j2 = 1.70327e-07/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.08316e-05/2.07494,j2 = 2.82233e-07/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000144563/2.07494,j2 = 4.72964e-07/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000387819/2.07494,j2 = 8.02002e-07/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000981406/2.07494,j2 = 1.37686e-06/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0023427/2.07494,j2 = 2.39458e-06/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00527513/2.07494,j2 = 4.22139e-06/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0112046/2.07494,j2 = 7.54826e-06/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0224497/2.07494,j2 = 1.36989e-05/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0424297/2.07494,j2 = 2.52498e-05/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0756447/2.07494,j2 = 4.7298e-05/0.999987,flat = 1/8), !coefficients=(c1 = 0.633376,c2 = 0.422093)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 2.3277,#gamma2 = 0.300238,#lambda2 = 0.963144,#mu1 = 26.181,#mu2 = 27.5092,#sigma1 = 0.827784,c1 = 0.633376,c2 = 0.422093)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=2.36032	#gamma2=0.235228	#lambda2=0.969641	#mu1=26.2194	#mu2=27.5277	#sigma1=0.855659	c1=0.591795	c2=0.43148
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 9.2706e-06/2.14481,j2 = 5.01349e-08/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 2.77938e-05/2.14481,j2 = 8.35487e-08/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 7.8897e-05/2.14481,j2 = 1.40795e-07/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000212054/2.14481,j2 = 2.40054e-07/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000539642/2.14481,j2 = 4.14329e-07/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00130028/2.14481,j2 = 7.24348e-07/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00296648/2.14481,j2 = 1.28346e-06/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00640796/2.14481,j2 = 2.30636e-06/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.013106/2.14481,j2 = 4.20605e-06/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0253802/2.14481,j2 = 7.78971e-06/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0465362/2.14481,j2 = 1.46613e-05/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0807906/2.14481,j2 = 2.80625e-05/0.999985,flat = 1/8), !coefficients=(c1 = 0.591795,c2 = 0.43148)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 2.36032,#gamma2 = 0.235228,#lambda2 = 0.969641,#mu1 = 26.2194,#mu2 = 27.5277,#sigma1 = 0.855659,c1 = 0.591795,c2 = 0.43148)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (5179.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	#delta2=2.60125	#gamma2=0.321119	#lambda2=0.97384	#mu1=26.1697	#mu2=27.5116	#sigma1=0.826774	c1=0.610449	c2=0.416314
# RooAddPdf::model[ c1 * g1 + c2 * j2 + [%] * flat ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.47857e-06/2.07241,j2 = 3.56485e-09/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 1.7502e-05/2.07241,j2 = 6.53745e-09/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 5.27347e-05/2.07241,j2 = 1.21463e-08/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.000149861/2.07241,j2 = 2.28773e-08/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00040167/2.07241,j2 = 4.37082e-08/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0010154/2.07241,j2 = 8.47623e-08/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.00242096/2.07241,j2 = 1.66964e-07/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0054441/2.07241,j2 = 3.343e-07/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0115465/2.07241,j2 = 6.80868e-07/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0230973/2.07241,j2 = 1.41166e-06/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.043577/2.07241,j2 = 2.9817e-06/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(g1 = 0.0775425/2.07241,j2 = 6.42068e-06/0.999998,flat = 1/8), !coefficients=(c1 = 0.610449,c2 = 0.416314)
#     ... (remaining 30 messages suppressed)
# RooNLLVar::nll_model_[ parameters=(#delta2,#gamma2,#lambda2,#mu1,#mu2,#sigma1,c1,c2) ]
#      function value is NAN @ parameters=(#delta2 = 2.60125,#gamma2 = 0.321119,#lambda2 = 0.97384,#mu1 = 26.1697,#mu2 = 27.5116,#sigma1 = 0.826774,c1 = 0.610449,c2 = 0.416314)
#
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.1419e-04  2.2106e-03  7.6774e-03  3.0313e-01  7.0034e-01  1.3148e+00  1.9856e+00  3.6864e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.003801 TO DIAGONAL.
#  FCN=4118.74 FROM HESSE     STATUS=NOT POSDEF     63 CALLS        1468 TOTAL
#                      EDM=0.00278051    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta2      2.21391e+00   1.33034e-01   2.80542e-04   1.89108e-01
#    2  #gamma2      3.57901e+00   3.36344e-01   4.80101e-04  -1.49158e-01
#    3  #lambda2     5.97482e-01   6.83288e-02   2.48834e-04   8.23462e-01
#    4  #mu1         2.55431e+01   7.65590e-02   3.83971e-04   1.34413e-01
#    5  #mu2         2.85334e+01   7.72828e-02   2.18738e-04  -6.08175e-01
#    6  #sigma1      5.12316e-01   6.52710e-02   6.06718e-04  -1.92432e-01
#    7  c1           1.85938e-01   3.94934e-02   5.84126e-04   8.89817e-02
#    8  c2           7.79105e-01   4.34453e-02   5.81366e-04  -1.08094e-01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=4118.66 FROM MIGRAD    STATUS=CONVERGED    2180 CALLS        2181 TOTAL
#                      EDM=0.000164752    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta2      2.35799e+00   2.38064e-01   2.32849e-04  -6.66977e-01
#    2  #gamma2      4.57350e+00   8.54954e-01   7.69809e-04  -2.46248e-01
#    3  #lambda2     4.72957e-01   1.36458e-01   1.97929e-04  -8.58897e-01
#    4  #mu1         2.55290e+01   9.92453e-02   3.84048e-04   2.37453e-01
#    5  #mu2         2.86926e+01   1.30736e-01   2.27007e-04   8.62375e-01
#    6  #sigma1      5.04558e-01   9.03159e-02   6.13487e-04  -1.09439e-01
#    7  c1           1.81096e-01   5.78534e-02   5.90537e-04  -1.78334e-03
#    8  c2           7.82893e-01   6.41650e-02   5.86665e-04   1.19308e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   5.686e-02 -1.145e-01 -2.640e-03 -1.054e-02 -2.262e-02 -1.227e-02 -8.808e-03  1.012e-02
#  -1.145e-01  8.499e-01 -9.995e-02 -2.513e-03  1.081e-01  1.898e-03  1.797e-03 -3.092e-03
#  -2.640e-03 -9.995e-02  1.871e-02  2.777e-03 -8.543e-03  2.980e-03  2.163e-03 -2.361e-03
#  -1.054e-02 -2.513e-03  2.777e-03  9.852e-03 -5.749e-04  8.174e-03  5.222e-03 -5.747e-03
#  -2.262e-02  1.081e-01 -8.543e-03 -5.749e-04  1.711e-02  5.635e-04  5.564e-04 -7.980e-04
#  -1.227e-02  1.898e-03  2.980e-03  8.174e-03  5.635e-04  8.163e-03  4.953e-03 -5.455e-03
#  -8.808e-03  1.797e-03  2.163e-03  5.222e-03  5.564e-04  4.953e-03  3.373e-03 -3.724e-03
#   1.012e-02 -3.092e-03 -2.361e-03 -5.747e-03 -7.980e-04 -5.455e-03 -3.724e-03  4.151e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.99855   1.000 -0.521 -0.081 -0.446 -0.725 -0.570 -0.636  0.659
#         2  0.99966  -0.521  1.000 -0.793 -0.027  0.897  0.023  0.034 -0.052
#         3  0.99930  -0.081 -0.793  1.000  0.205 -0.478  0.241  0.272 -0.268
#         4  0.93790  -0.446 -0.027  0.205  1.000 -0.044  0.912  0.906 -0.899
#         5  0.99528  -0.725  0.897 -0.478 -0.044  1.000  0.048  0.073 -0.095
#         6  0.95381  -0.570  0.023  0.241  0.912  0.048  1.000  0.944 -0.937
#         7  0.99609  -0.636  0.034  0.272  0.906  0.073  0.944  1.000 -0.995
#         8  0.99640   0.659 -0.052 -0.268 -0.899 -0.095 -0.937 -0.995  1.000

# %%
nevent = ROOT.RooRealVar("#nevent", "#number of fitted events", len(K_peak_data))
sum_frac1_frac2 = ROOT.RooFormulaVar("sum_c1_c2", "@0 + @1", ROOT.RooArgList(frac1, frac2))
signal = ROOT.RooProduct("event yield", "nevent * (frac1 + frac2)", ROOT.RooArgList(nevent, sum_frac1_frac2))

print(f'The number of events in the peak is {signal.getVal():.1f} with error {signal.getPropagatedError(fit_result):.1f}')
# Out:
# The number of events in the peak is 2954.6 with error 26.7

# %%
def gauss(x, mu1, sigma1):
    return 1 / np.sqrt(2 * np.pi * sigma1**2) * np.exp( -(x - mu1)**2 / (2 * sigma1**2) )

def johnson(x, mu2, lambda2, gamma2, delta2):
    return delta2 / (lambda2 * np.sqrt(2 * np.pi)) * 1/np.sqrt(1 + ( (x - mu2) / lambda2 )**2 ) * np.exp( -1/2 * (gamma2 + delta2 * np.arcsinh( (x - mu2) / lambda2) )**2 )

def uniform(x, xrange):
    return 1.0 / xrange

def gauss_johnson_flat(x, c1, c2, mu1, sigma1, mu2, lambda2, gamma2, delta2, xrange):
    gauss1 = gauss(x, mu1, sigma1)
    johnson2 = johnson(x, mu2, lambda2, gamma2, delta2)
    flat = uniform(x, xrange)

    PDF = c1 * gauss1 + c2 * johnson2 + (1 - c1 - c2) * flat

    return PDF

# %%
x_plot = np.linspace(22, 30, 101)
mu1, mu1_err, mu2, mu2_err = mean_1.getVal(), mean_1.getError(), mean_2.getVal(), mean_2.getError()
sigma1, sigma1_err = sigma_1.getVal(), sigma_1.getError()
delta2, delta2_err = delta_2.getVal(), delta_2.getError()
gamma2, gamma2_err = gamma_2.getVal(), gamma_2.getError()
lambda2, lambda2_err = lambda_2.getVal(), lambda_2.getError()
c1, c1_err, c2, c2_err = frac1.getVal(), frac1.getError(), frac2.getVal(), frac2.getError()
xrange = max(K_peak_bins) - min(K_peak_bins)

PDF = np.array([gauss_johnson_flat(i, c1, c2, mu1, sigma1, mu2, lambda2, gamma2, delta2, xrange) for i in x_plot])

# %%
obs = counts[9:-7]
obs_err = counts_err[9:-7]
exp = np.array([gauss_johnson_flat(i, c1, c2, mu1, sigma1, mu2, lambda2, gamma2, delta2, xrange) for i in bin_centers[9:-7]]) * binWidth * sum(counts)
ddof = 8
chi2 = sum( (obs - exp)**2 / obs_err**2 ) / (len(obs) - ddof)
print(chi2)
# Out:
# 1.2771112870814836

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(K_peak_data, bins=K_peak_bins, label = 'PTOFamps', alpha = 1)
plt.hist(K_peak_data, bins=K_peak_bins, histtype='step', color = 'black', lw = 0.2)
plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / (0.2 $\mathrm{\mu A}$)")

plt.plot(x_plot, PDF*len(K_peak_data)*np.diff(K_peak_bins)[0], color = 'black', 
         label = r'$\mathrm{c_1}$ Gauss($\mathrm{\mu_1}$, $\mathrm{\sigma_1}$) + $\mathrm{c_2}$ Johnson($\mathrm{\mu_2}$, $\mathrm{\lambda_2}$, $\mathrm{\gamma_2}$, $\mathrm{\delta_2}$) + (1$\mathrm{- c_1 - c_2}$) Uniform' + 
           '\n'+r'$\mathrm{c_1}$' + f' = {c1:.2f} '+r'$\pm$'+f' {c1_err:.2f} ' + 
           '\n'+r'$\mathrm{c_2}$' + f' = {c2:.2f} ' + r'$\pm$'+f' {c2_err:.2f}' +
           '\n'+r'$\mathrm{\mu_1}$'+f' = {mu1:.1f} '+ r'$\pm$'+f'{mu1_err:.1f} ' + 
           '\n'+r'$\mathrm{\sigma_1}$'+f' = {sigma1:.2f} '+r'$\pm$'+f' {sigma1_err:.2f}' +
           '\n'+r'$\mathrm{\mu_2}$'+f' = {mu2:.1f} '+r'$\pm$'+f' {mu2_err:.1f} ' + 
           '\n'+r'$\mathrm{\lambda_2}$'+f' = {lambda2:.1f} '+r'$\pm$'+f' {lambda2_err:.1f}'
           '\n'+r'$\mathrm{\gamma_2}$'+f' = {gamma2:.1f} '+r'$\pm$'+f' {gamma2_err:.1f}'
           '\n'+r'$\mathrm{\delta_2}$'+f' = {delta2:.1f} '+r'$\pm$'+f' {delta2_err:.1f}'
           '\n'+r'$\mathrm{\chi^2}$ = '+f'{np.round(chi2, 2)}')

plt.errorbar(bin_centers, counts, yerr = counts_err, ls = "None", color='black', capsize = 1.5, elinewidth=0.2, capthick = 0.2)
plt.scatter(bin_centers, counts, color = 'black', s = 0.5)
plt.axvline(bin_centers[9] - binWidth / 2, 0, 0.1, lw = 0.5, color = 'black', ls = '--')
plt.axvline(bin_centers[-8] + binWidth / 2, 0, 0.1, lw = 0.5, color = 'black', ls = '--')

plt.legend(fontsize = 5.8, loc = 'upper left')

plt.ylim(0, 375)
# Out:
# (0.0, 375.0)

# %% [markdown]
# # Let's fit the L-peak with a skewed Gaussian and a flat background
# $$
# model = c_1 \cdot Johnson(\mu_1,\sigma_1,) + (1-c_1) \cdot Uniform
# $$

# %%
counts, bin_edges = np.histogram(L_peak_data, bins=L_peak_bins)
binWidth = np.diff(L_peak_bins)[0]
bin_centers = bin_edges[:-1] + binWidth / 2
counts_err = np.sqrt(counts)
counts_err[counts_err == 0] = np.inf

# Observable
x = ROOT.RooRealVar("x", "x", 2.5, 5)

# Parameters
mean_1 = ROOT.RooRealVar("#mu1", "#mu", 3.5, 2, 6)
lambda_1 = ROOT.RooRealVar("#lambda1", "#lambda", 1, 0.1, 4)
delta_1 = ROOT.RooRealVar("#delta1", "#delta", 4, 0.1, 5)
gamma_1 = ROOT.RooRealVar("#gamma1", "#gamma", 3, 0.1, 5)

# Distributions
j1 = ROOT.RooJohnson("j1", "j1", x, mean_1, lambda_1, gamma_1, delta_1)
flat = ROOT.RooUniform("flat", "flat", x)

# Weights of distributions
frac1 = ROOT.RooRealVar("c1", "c", 0.5, 0.0, 1.0)

# Weighted sum of distributions
pdf = ROOT.RooAddPdf("model", "model", [j1, flat], [frac1])
# Convert numpy array into RooFit object
#data = ROOT.RooDataSet.from_numpy({"x": L_peak_data},[x],name='1_Johnson',title='1_Johnson')
data = ROOT.RooDataHist.from_numpy(counts, [x], bins=[L_peak_bins])

# %%
nll = pdf.createNLL(data)
m = ROOT.RooMinimizer(nll)
m.migrad()
fit_result = m.save()

frame = make_frame(x,data,pdf)

pdf.paramOn(frame)
make_plot(frame)
# Out:
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 #delta1      4.00000e+00  4.90000e-01    1.00000e-01  5.00000e+00
#      2 #gamma1      3.00000e+00  4.90000e-01    1.00000e-01  5.00000e+00
#      3 #lambda1     1.00000e+00  3.90000e-01    1.00000e-01  4.00000e+00
#      4 #mu1         3.50000e+00  4.00000e-01    2.00000e+00  6.00000e+00
#      5 c1           5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        2500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=283.658 FROM MIGRAD    STATUS=INITIATE       59 CALLS          60 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta1      4.99994e+00   4.90000e-01   0.00000e+00  -3.24958e-01
#    2  #gamma1      1.24834e+00   4.90000e-01  -7.44843e-01   4.43341e+02
#    3  #lambda1     1.00000e+00   3.90000e-01   0.00000e+00   1.56177e+02
#    4  #mu1         3.50000e+00   4.00000e-01   0.00000e+00  -2.04860e+03
#    5  c1           5.00000e-01   1.00000e-01   0.00000e+00  -2.88617e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-6.11009 FROM HESSE     STATUS=OK             31 CALLS         560 TOTAL
#                      EDM=0.0839714    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta1      2.15161e+00   3.71009e-01   2.13549e-05  -2.60465e-02
#    2  #gamma1      4.04354e+00   1.40776e+00   5.10571e-05   1.87894e-01
#    3  #lambda1     1.11458e-01   5.56342e-02   2.58963e-05   9.90767e-01
#    4  #mu1         3.90294e+00   6.62299e-02   6.71784e-06  -1.82799e+00
#    5  c1           8.89240e-01   2.11097e-02   1.15395e-04  -1.13598e-02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=-6.19398 FROM MIGRAD    STATUS=CONVERGED     645 CALLS         646 TOTAL
#                      EDM=2.98739e-05    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.4 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  #delta1      2.25682e+00   3.01850e-01   7.36321e-04  -6.78183e-01
#    2  #gamma1      4.59139e+00   9.94846e-01  -9.29093e-04  -2.78831e-01
#    3  #lambda1     1.00625e-01   3.73973e-02   3.51409e-05   5.27842e-01
#    4  #mu1         3.92389e+00   5.14769e-02  -1.16429e-04  -1.90568e+00
#    5  c1           8.88693e-01   2.11121e-02  -1.20841e-05  -6.75284e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=0.5
#   9.158e-02 -3.345e-01 -2.834e-03  1.479e-02 -6.612e-04
#  -3.345e-01  1.248e+00  1.070e-02 -5.607e-02  1.718e-03
#  -2.834e-03  1.070e-02  9.379e-05 -4.740e-04  1.507e-05
#   1.479e-02 -5.607e-02 -4.740e-04  2.650e-03 -3.718e-05
#  -6.612e-04  1.718e-03  1.507e-05 -3.718e-05  4.464e-04
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1  0.99851   1.000 -0.989 -0.967  0.949 -0.103
#         2  0.99975  -0.989  1.000  0.989 -0.975  0.073
#         3  0.99837  -0.967  0.989  1.000 -0.951  0.074
#         4  0.99570   0.949 -0.975 -0.951  1.000 -0.034
#         5  0.30270  -0.103  0.073  0.074 -0.034  1.000

# %%
nevent = ROOT.RooRealVar("#nevent", "#number of fitted events", len(L_peak_data))
signal = ROOT.RooProduct("event yield", "nevent * frac1", ROOT.RooArgList(nevent, frac1))

print(f'The number of events in the peak is {signal.getVal():.1f} with error {signal.getPropagatedError(fit_result):.1f}')
# Out:
# The number of events in the peak is 367.9 with error 8.7

# %%
def johnson_flat(x, c1, mu1, lambda1, gamma1, delta1, xrange):
    Johnson1 = (delta1 / (lambda1 * np.sqrt(2 * np.pi)) * 1/np.sqrt(1 + ( (x - mu1) / lambda1 )**2 ) * np.exp( -1/2 * (gamma1 + delta1 * np.arcsinh( (x - mu1) / lambda1) )**2 ))
    flat = 1.0 / xrange

    PDF = c1 * Johnson1 + (1 - c1) * flat

    return PDF

# %%
x_plot = np.linspace(2.5, 5, 101)
delta1, delta1_err = delta_1.getVal(), delta_1.getError()
gamma1, gamma1_err = gamma_1.getVal(), gamma_1.getError()
lambda1, lambda1_err = lambda_1.getVal(), lambda_1.getError()
mu1, mu1_err = mean_1.getVal(), mean_1.getError()
c1, c1_err = frac1.getVal(), frac1.getError()
xrange = max(L_peak_bins) - min(L_peak_bins)

PDF = np.array([johnson_flat(i, c1, mu1, lambda1, gamma1, delta1, xrange) for i in x_plot])

# %%
obs = counts[6:-22]
obs_err = counts_err[6:-22]
exp = np.array([johnson_flat(i, c1, mu1, lambda1, gamma1, delta1, xrange) for i in bin_centers[6:-22]]) * binWidth * sum(counts)
ddof = 5
chi2 = sum( (obs - exp)**2 / obs_err**2 ) / (len(obs) - ddof - 1) # subtracting one to exclude 0 bin
print(chi2)
# Out:
# 1.6667217423671161

# %%
plt.figure(figsize=(4,3), dpi=200)
plt.hist(L_peak_data, bins=L_peak_bins, label = 'PTOFamps', alpha = 1)
plt.hist(L_peak_data, bins=L_peak_bins, histtype='step', color = 'black', lw = 0.2)
plt.xlabel(r"Amplitude [$\mathrm{\mu A}$]")
plt.ylabel("Count / (0.05 $\mathrm{\mu A}$)")


plt.plot(x_plot, PDF*len(L_peak_data)*np.diff(L_peak_bins)[0], color = 'black', 
         label = r'$\mathrm{c_1}$ Johnson($\mathrm{\mu}$, $\mathrm{\lambda}$, $\mathrm{\gamma}$, $\mathrm{\delta}$) + (1$\mathrm{- c_1}$) Uniform' + 
          '\n' + r'$\mathrm{c_1}$' + f' = {c1:.2f} ' + r'$\pm$' + f' {c1_err:.2f}'
          '\n' + r'$\mathrm{\mu}$' + f' = {mu1:.2f} ' + f'$\pm$' + f' {mu1_err:.2f}'
          '\n' + r'$\mathrm{\lambda}$' + f' = {lambda1:.2f} ' + r'$\pm$' + f' {lambda1_err:.2f}'
          '\n' + r'$\mathrm{\gamma}$' + f' = {gamma1:.1f} ' + r'$\pm$' + f' {gamma1_err:.1f}'
          '\n' + r'$\mathrm{\delta}$' + f' = {delta1:.1f} ' + r'$\pm$' + f' {delta1_err:.1f}'
          '\n' + r'$\mathrm{\chi^2}$ = ' + f'{np.round(chi2, 2)}')

plt.errorbar(bin_centers, counts, yerr = np.sqrt(counts), ls = "None", color='black', capsize = 1.5, elinewidth=0.2, capthick = 0.2)
plt.scatter(bin_centers, counts, color = 'black', s = 0.5)

plt.axvline(bin_centers[6] - binWidth / 2, 0, 0.15, lw = 0.5, color = 'black', ls='--')
plt.axvline(bin_centers[-23] + binWidth / 2, 0, 0.15, lw = 0.5, color = 'black', ls='--')

plt.legend(fontsize = 7, loc = 'upper left')

plt.ylim(0, 70)
# Out:
# (0.0, 70.0)

# %% [markdown]
# ## Determine how many events ought to have happened in each of the series windows

# %%
import datetime

# %%
# Cf252 radioactive properties
Cf252_halflife = 8.341e7 # s
Cf252_lifetime = Cf252_halflife / np.log(2) # s
Cf252_lambda   = 1 / Cf252_lifetime # Hz

# Ge-71 radioactive properties
Ge71_halflife = 990835 # s
Ge71_lifetime = Ge71_halflife / np.log(2) # s
Ge71_lambda = 1 / Ge71_lifetime

# %%
activity    = 37000                                                # activity of Cf252 at reference time; given in Hz
t_ref       = datetime.datetime(2020, 3, 15, 00, 0).timestamp()    # reference time of nominal activity; Unix time
#sf_prob     = 0.031                                                # spontaneous fission probability
#n_per_sf    = 3.7                                                  # neutrons emitted per spontaneous fission
activ_prob = 9208e-9                                              # Ge activations per neutron emitted; found using sourcesim w/ CUTE geometry

# rate of Ge activation during exposure
GeActivRate = activity * activ_prob # activations / second

# %%
# find total activations with N = int[ A exp( -lambda_Cf252 (t + t0) ) * exp(-lambda_Ge71 (T - t) ) ] dt + N0 exp(-lambda_Ge71 T)
def integrate_activations(N, T, t0):
    return (GeActivRate / (Cf252_lambda - Ge71_lambda) * ( np.exp(- Cf252_lambda * t0 - Ge71_lambda * T) - np.exp(-Cf252_lambda * (T + t0)) ) + 
            N * np.exp(-Ge71_lambda * T) )

# %%
exposures = {i: {'t0': None, 'dt': None} for i in range(8)}

exposures[0]['t0'] = datetime.datetime(2023, 10, 18, 15, 28, 0).timestamp()
exposures[0]['dt'] = (datetime.datetime(2023, 10, 23, 10, 45, 0) - datetime.datetime(2023, 10, 18, 15, 28, 0)).total_seconds()

exposures[1]['t0'] = datetime.datetime(2023, 10, 30, 8, 56, 0).timestamp()
exposures[1]['dt'] = (datetime.datetime(2023, 11, 2, 10, 58, 0) - datetime.datetime(2023, 10, 30, 8, 56, 0)).total_seconds()

exposures[2]['t0'] = datetime.datetime(2023, 11, 7, 9, 51, 0).timestamp()
exposures[2]['dt'] = (datetime.datetime(2023, 11, 10, 12, 45, 0) - datetime.datetime(2023, 11, 7, 9, 51, 0)).total_seconds()

exposures[3]['t0'] = datetime.datetime(2023, 11, 30, 8, 37, 0).timestamp()
exposures[3]['dt'] = (datetime.datetime(2023, 11, 30, 9, 13, 0) - datetime.datetime(2023, 11, 30, 8, 37, 0)).total_seconds()

exposures[4]['t0'] = datetime.datetime(2023, 11, 30, 9, 33, 0).timestamp()
exposures[4]['dt'] = (datetime.datetime(2023, 11, 30, 10, 35, 0) - datetime.datetime(2023, 11, 30, 9, 33, 0)).total_seconds()

exposures[5]['t0'] = datetime.datetime(2023, 11, 30, 10, 49, 0).timestamp()
exposures[5]['dt'] = (datetime.datetime(2023, 12, 1, 15, 10, 0) - datetime.datetime(2023, 11, 30, 10, 49, 0)).total_seconds()

exposures[6]['t0'] = datetime.datetime(2023, 12, 6, 8, 2, 0).timestamp()
exposures[6]['dt'] = (datetime.datetime(2023, 12, 6, 15, 20, 0) - datetime.datetime(2023, 12, 6, 8, 2, 0)).total_seconds()

exposures[7]['t0'] = datetime.datetime(2023, 12, 12, 15, 22, 0).timestamp()
exposures[7]['dt'] = (datetime.datetime(2023, 12, 13, 8, 55, 0) - datetime.datetime(2023, 12, 12, 15, 22, 0)).total_seconds()

# %%
# data-taking window
datataking_start = datetime.datetime(2023, 12, 16, 0, 0, 0).timestamp()
datataking_end = datetime.datetime(2023, 12, 19, 0, 0, 0).timestamp()

# %%
s2day = 1.157e-5
t_1018 = datetime.datetime(2023, 10, 18, 0, 0, 0).timestamp()
t_1222 = datetime.datetime(2023, 12, 22, 0, 0, 0).timestamp()

N = 0
for i in range(8):
    t0      = exposures[i]['t0']
    t0_next = exposures[i+1]['t0'] if i != 7 else t_1222
    dt      = exposures[i]['dt']
    t       = np.arange(t0, t0 + dt, 1)
    activ   = integrate_activations(N, t - t0, t0 - t_ref)

    if i == 7:
        plt.plot((t - t_1018)*s2day, activ, color = 'C0', lw = 2, label = 'exposure period')
    else:
        plt.plot((t - t_1018)*s2day, activ, color = 'C0', lw = 2)

    N0 = activ[-1]
    delta_t = np.linspace(0, t0_next - t[-1], 101)

    if i == 0:
        plt.plot((t0 + dt + delta_t - t_1018)*s2day, N0 * np.exp(-Ge71_lambda * delta_t), color = 'C2', lw = 2, label = 'non-exposure period')
    else:
        plt.plot((t0 + dt + delta_t - t_1018)*s2day, N0 * np.exp(-Ge71_lambda * delta_t), color = 'C2', lw = 2)
    N = N0 * np.exp(-Ge71_lambda * delta_t)[-1]

    if i == 7:
        
        datataking_t = np.linspace(datataking_start - t_1018, datataking_end - t_1018, 100)*s2day
        datataking_N = np.interp(datataking_t, (t0 + dt + delta_t - t_1018)*s2day, N0 * np.exp(-Ge71_lambda * delta_t))

        plt.plot(datataking_t, datataking_N, color = '#D72B22', lw = 2.2, label = 'data-taking period')
        plt.scatter([datataking_t[0]], [datataking_N[0]], color = '#AA2B22', s = 20, marker=(2, 0, -35), zorder = 1e3)
        plt.scatter([datataking_t[-1]], [datataking_N[-1]], color = '#AA2B22', s = 20, marker=(2, 0, -32), zorder = 1e3)


plt.ylim(0, 70000)
plt.xlim(0, (t_1222 - t_1018) * s2day)
plt.xlabel('Time since 2023/10/18 [days]')
plt.ylabel('Number of Ge-71 Nuclei')
plt.legend(fontsize = 8)

# %%
#### starting with 0 nuclei activated ####
N = 0

N = integrate_activations(N, exposures[0]['dt'], exposures[0]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[1]['t0'] - (exposures[0]['t0'] + exposures[0]['dt'])))

N = integrate_activations(N, exposures[0]['dt'], exposures[0]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[1]['t0'] - (exposures[0]['t0'] + exposures[0]['dt'])))

N = integrate_activations(N, exposures[1]['dt'], exposures[1]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[2]['t0'] - (exposures[1]['t0'] + exposures[1]['dt'])))

N = integrate_activations(N, exposures[2]['dt'], exposures[2]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[3]['t0'] - (exposures[2]['t0'] + exposures[2]['dt'])))

N = integrate_activations(N, exposures[3]['dt'], exposures[3]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[4]['t0'] - (exposures[3]['t0'] + exposures[3]['dt'])))

N = integrate_activations(N, exposures[4]['dt'], exposures[4]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[5]['t0'] - (exposures[4]['t0'] + exposures[4]['dt'])))

N = integrate_activations(N, exposures[5]['dt'], exposures[5]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[6]['t0'] - (exposures[5]['t0'] + exposures[5]['dt'])))

N = integrate_activations(N, exposures[6]['dt'], exposures[6]['t0'] - t_ref)
N = N * np.exp(-Ge71_lambda * (exposures[7]['t0'] - (exposures[6]['t0'] + exposures[6]['dt'])))

N = integrate_activations(N, exposures[7]['dt'], exposures[7]['t0'] - t_ref)
print(N)
N_start = N * np.exp(-Ge71_lambda * (datataking_start - (exposures[7]['t0'] + exposures[7]['dt'])))
N_end = N * np.exp(-Ge71_lambda * (datataking_end - (exposures[7]['t0'] + exposures[7]['dt'])))

print(N_start - N_end)
# Out:
# 27062.373730182793
# 3828.681080851886

# %%
N_tot = 0
for sn in np.unique(df_rqs['SeriesNumber']):
    snCut = df_rqs['SeriesNumber'] == sn
    evtTimes = df_rqs['EventTime'][snCut]
    sn_start = min(evtTimes)
    sn_end = max(evtTimes)

    N_start = N * np.exp(-Ge71_lambda * (sn_start - (exposures[7]['t0'] + exposures[7]['dt'])))
    N_end = N * np.exp(-Ge71_lambda * (sn_end - (exposures[7]['t0'] + exposures[7]['dt'])))
    print(f'{np.round(N_start - N_end)} Ge-71 events in series {int(sn)}')

    N_tot += N_start - N_end

print(f'{N_tot} total Ge-71 events')
# Out:
# 160.0 Ge-71 events in series 23231216013604
# 289.0 Ge-71 events in series 23231216043946
# 33.0 Ge-71 events in series 23231216100125
# 120.0 Ge-71 events in series 23231216115012
# 150.0 Ge-71 events in series 23231216145300
# 58.0 Ge-71 events in series 23231216182937
# 14.0 Ge-71 events in series 23231216194929
# 61.0 Ge-71 events in series 23231216211119
# 19.0 Ge-71 events in series 23231216233807
# 147.0 Ge-71 events in series 23231217135018
# 193.0 Ge-71 events in series 23231217171613
# 252.0 Ge-71 events in series 23231217212512
# 209.0 Ge-71 events in series 23231218093255
# 152.0 Ge-71 events in series 23231218152721
# 80.0 Ge-71 events in series 23231218190035
# 245.0 Ge-71 events in series 23231218223530
# 338.0 Ge-71 events in series 23231219034952
# 313.0 Ge-71 events in series 23231219110331
# 301.0 Ge-71 events in series 23231219184002
# 176.0 Ge-71 events in series 23231220012745
# 3311.3626285097052 total Ge-71 events

# %%
3311.3626285097052 * 0.02
# Out:
# 66.22725257019411
