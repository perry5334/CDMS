# %%
import cdms
from CDMSDataCatalog import *
dc = CDMSDataCatalog()

import os
os.environ["http_proxy"]="http://10.73.132.63:8080"
os.environ["https_proxy"]="http://10.73.132.63:8080"
os.environ["ftp_proxy"]="http://10.73.132.63:8080"

# %%
series_list=['23231216_013604', '23231216_043946', '23231216_100125', '23231216_145300', '23231216_182937', '23231216_194929', '23231216_211119', '23231216_233807', 
             '23231217_135018', '23231217_171613', '23231217_212512', '23231218_093255', '23231218_152721', '23231218_190035', '23231218_223530', '23231219_034952', 
             '23231219_110331', '23231219_184002', '23231216_115012', '23231220_012745'] # Ge calibration

# %%
Facility = 'CUTE'
#ProdTag = 'CUTE_T3_GeActivation_v2.1.1_V05-00_P0.2.'
ProdTag = 'CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3'
nFridgeRun  = 37
nMergeLevel = 1

# %%
SearchPath = '/CDMS/'+Facility+'/**'
sAll = str('ProdTag=="{}"'.format(ProdTag))
sRaw = str('ProdTag=="{}" && fileFormat=="midas"'.format(ProdTag))
sRQunmerged   = str('ProdTag=="{}" && ProdStep=="BatRoot" && nMergeLevel==0'.format(ProdTag))
sRQsubmerged  = str('ProdTag=="{}" && ProdStep=="BatRoot" && nMergeLevel==1'.format(ProdTag))

# %%
dsRQsubmerged = dc.search(SearchPath, 'SLAC', query=sRQsubmerged)

# %%
dsRQsubmerged[:50]
# Out:
# [<CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_013604.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_043946.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_100125.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_115012.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_145300.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_182937.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_194929.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_211119.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231216_233807.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231217_135018.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231217_171613.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231217_212512.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231218_093255.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231218_152721.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231218_190035.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231218_223530.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231219_034952.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231219_110331.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231219_184002.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231220_012745.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231223_143801.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231223_201902.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231224_020002.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231224_074103.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231224_132204.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231224_190305.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231225_004407.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231225_062509.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231225_120610.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231225_174711.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231225_183411.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231226_001512.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231226_055613.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231226_113713.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231226_171815.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231227_155236.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231227_213338.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231228_031439.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231228_085541.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231228_162307.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231228_182306.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_000407.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_181225.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_235327.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_053429.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_111531.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_165633.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_205226.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231231_145256.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231231_203357.root>]

# %%
print("Default fetch dir: ", dc.default_fetchdir)
# Out:
# Default fetch dir:  /scratch/group/mitchcomp/CDMS/data

# %%
dc.fetch(dsRQsubmerged[40:50])
# Out:
# Need to download 10.3GiB ( 10 files ) from catalog
# Do you want to proceed? (y/n):  y
# Total progress: 100%|██████████| 10.3G/10.3G [10:27<00:00, 17.5MB/s]
# Download finished
# [<CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231228_182306.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_000407.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_181225.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231229_235327.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_053429.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_111531.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_165633.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231230_205226.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231231_145256.root>,
#  <CDMSDataset Class, Name: CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3_23231231_203357.root>]
