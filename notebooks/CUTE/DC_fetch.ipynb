# %%
import cdms
from CDMSDataCatalog import *
dc = CDMSDataCatalog()

import os
os.environ["http_proxy"]="http://10.73.132.63:8080"
os.environ["https_proxy"]="http://10.73.132.63:8080"
os.environ["ftp_proxy"]="http://10.73.132.63:8080"

# %%
series_list=['23231216_013604', '23231216_043946', '23231216_100125', '23231216_145300', '23231216_182937', '23231216_194929', '23231216_211119', '23231216_233807', 
             '23231217_135018', '23231217_171613', '23231217_212512', '23231218_093255', '23231218_152721', '23231218_190035', '23231218_223530', '23231219_034952', 
             '23231219_110331', '23231219_184002', '23231216_115012', '23231220_012745'] # Ge calibration

# %%
Facility = 'CUTE'
#ProdTag = 'CUTE_T3_GeActivation_v2.1.1_V05-00_P0.2.'
ProdTag = 'CUTE_T3_Calibration_v3.0.0_V05-03_P0.3.3'
nFridgeRun  = 37
nMergeLevel = 1

# %%
SearchPath = '/CDMS/'+Facility+'/**'
sAll = str('ProdTag=="{}"'.format(ProdTag))
sRaw = str('ProdTag=="{}" && fileFormat=="midas"'.format(ProdTag))
sRQunmerged   = str('ProdTag=="{}" && ProdStep=="BatRoot" && nMergeLevel==0'.format(ProdTag))
sRQsubmerged  = str('ProdTag=="{}" && ProdStep=="BatRoot" && nMergeLevel==1'.format(ProdTag))

# %%
#dsRQsubmerged = dc.search(SearchPath, 'SLAC', query=sRQsubmerged)
ds = dc.search("/CDMS/CUTE/R37/Raw/" + series_list[0])

# %%
ds
# Out:
# [<CDMSDataset Class, Name: 23231216_013604_F0001.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0002.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0003.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0004.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0005.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0006.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0007.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0008.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0009.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0010.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0011.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0012.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0013.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0014.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0015.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0016.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0017.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0018.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0019.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0020.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0021.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0022.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0023.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0024.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0025.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0026.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0027.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0028.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0029.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0030.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0031.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0032.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0033.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0034.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0035.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0036.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0037.mid.gz>]

# %%
print("Default fetch dir: ", dc.default_fetchdir)
# Out:
# Default fetch dir:  /scratch/group/mitchcomp/CDMS/data

# %%
dc.fetch(ds)
# Out:
# Need to download 31.6GiB ( 37 files ) from catalog
# Do you want to proceed? (y/n):  y
# Total progress: 100%|██████████| 31.6G/31.6G [09:19<00:00, 60.8MB/s]
# Download finished
# [<CDMSDataset Class, Name: 23231216_013604_F0001.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0002.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0003.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0004.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0005.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0006.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0007.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0008.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0009.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0010.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0011.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0012.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0013.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0014.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0015.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0016.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0017.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0018.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0019.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0020.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0021.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0022.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0023.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0024.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0025.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0026.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0027.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0028.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0029.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0030.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0031.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0032.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0033.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0034.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0035.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0036.mid.gz>,
#  <CDMSDataset Class, Name: 23231216_013604_F0037.mid.gz>]
